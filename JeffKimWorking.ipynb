# %%
import pandas as pd
import zipfile

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Unnamed: 0 CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y           0.0
# 1     5008805           M            Y               Y           0.0
# 2     5008806           M            Y               Y           0.0
# 3     5008808           F            N               Y           0.0
# 4     5008809           F            N               Y           0.0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          0.258721               Working               Higher education
# 1          0.258721               Working               Higher education
# 2          0.055233               Working  Secondary / secondary special
# 3          0.156977  Commercial associate  Secondary / secondary special
# 4          0.156977  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
edulist = df[['NAME_EDUCATION_TYPE']]
print(edulist.shape)
edulist.head()
# Out:
# (36457, 1)
#              NAME_EDUCATION_TYPE
# 0               Higher education
# 1               Higher education
# 2  Secondary / secondary special
# 3  Secondary / secondary special
# 4  Secondary / secondary special

# %%
#Replace the Education Types according to labeldict
labeldict = {'Lower secondary': 0, 'Secondary / secondary special':1, 'Incomplete higher': 2, 'Higher education': 3, 'Academic degree':1}
df = df.replace(labeldict)
df.head()
# Out:
#    Unnamed: 0 CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0     5008804           M            Y               Y           0.0
# 1     5008805           M            Y               Y           0.0
# 2     5008806           M            Y               Y           0.0
# 3     5008808           F            N               Y           0.0
# 4     5008809           F            N               Y           0.0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0          0.258721               Working                    3
# 1          0.258721               Working                    3
# 2          0.055233               Working                    1
# 3          0.156977  Commercial associate                    1
# 4          0.156977  Commercial associate                    1
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0        Civil marriage   Rented apartment    0.744324       0.029324
# ...

# %%
df.to_csv("EncodedEducationType.csv")
